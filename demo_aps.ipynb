# %%
print("Hola, mundo desde Jupyter en VS Code")
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 200)
y = np.sin(x)

plt.plot(x, y)
plt.title("Onda sinusoidal")
plt.xlabel("Tiempo")
plt.ylabel("Amplitud")
plt.grid(True)
plt.show()
# Out:
# Hola, mundo desde Jupyter en VS Code
