# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal

#PULSITO
M = 8
x = np.zeros(M)
x[3:5]=1 #ELEMENTOS 3,4,5,6 VALEN 1
print(x)

plt.subplot()
#plt.plot(x)
plt.stem(x)
# Out:
# [0. 0. 0. 1. 1. 0. 0. 0.]
# <StemContainer object of 3 artists>

# %%
import scipy.signal as signal

R = signal.correlate(x,x)

plt.subplot(2, 1, 2)
plt.stem(R)
# Out:
# <StemContainer object of 3 artists>

# %%
print(x)
# Out:
# [0. 0. 0. 1. 1. 0. 0. 0.]

# %%
N=8
n=np.arange(0,N-1)
x= 4 + (3*np.sin(2*np.pi*n/2))

print(x)
# Out:
# [4. 4. 4. 4. 4. 4. 4.]
